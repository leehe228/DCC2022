# %%
#-*-coding:utf-8-*-

# import libraries
import cv2 as cv
import os
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
# base directory
base_dir = "/home/dmsai2/Desktop/DCC2022/data"

# %%
# load class list from directory
cls_list = os.listdir(base_dir)
cls_list
# Out:
# ['L2_21',
#  'L2_24',
#  'L2_15',
#  'L2_27',
#  'L2_30',
#  'L2_50',
#  'L2_40',
#  'L2_39',
#  'L2_20',
#  'L2_45',
#  'L2_3',
#  'L2_12',
#  'L2_41',
#  'L2_10',
#  'L2_34',
#  'L2_52',
#  'L2_33',
#  'L2_46',
#  'L2_44',
#  'L2_25']

# %%
# change class name to integer
clsdict = {}
for i, cls in enumerate(cls_list):
    clsdict[i] = cls
clsdict
# Out:
# {0: 'L2_21',
#  1: 'L2_24',
#  2: 'L2_15',
#  3: 'L2_27',
#  4: 'L2_30',
#  5: 'L2_50',
#  6: 'L2_40',
#  7: 'L2_39',
#  8: 'L2_20',
#  9: 'L2_45',
#  10: 'L2_3',
#  11: 'L2_12',
#  12: 'L2_41',
#  13: 'L2_10',
#  14: 'L2_34',
#  15: 'L2_52',
#  16: 'L2_33',
#  17: 'L2_46',
#  18: 'L2_44',
#  19: 'L2_25'}

# %%
cnt = 0
data_list = {}

for cls in cls_list:
    imlist = os.listdir(base_dir + "/" + cls)
    print(cls, end=' : ')
    print(len(imlist))
    cnt = cnt + len(imlist)
    data_list[cls] = imlist
    print("-"*12)

print("num of class :", len(cls_list))
print("num of data :", cnt)
# Out:
# L2_21 : 410
# ------------
# L2_24 : 782
# ------------
# L2_15 : 1509
# ------------
# L2_27 : 426
# ------------
# L2_30 : 364
# ------------
# L2_50 : 781
# ------------
# L2_40 : 180
# ------------
# L2_39 : 454
# ------------
# L2_20 : 410
# ------------
# L2_45 : 631
# ------------
# L2_3 : 595
# ------------
# L2_12 : 518
# ------------
# L2_41 : 593
# ------------
# L2_10 : 1893
# ------------
# L2_34 : 419
# ------------
# L2_52 : 382
# ------------
# L2_33 : 6206
# ------------
# L2_46 : 2214
# ------------
# L2_44 : 547
# ------------
# L2_25 : 6189
# ------------
# num of class : 20
# num of data : 25503

# %%
img1 = cv.imread(base_dir + "/L2_15/" + data_list['L2_15'][24])
img1.shape
plt.imshow(img1)

# %%
resize_img = cv.resize(img1, (400, 400))
resize_img.shape
# Out:
# (400, 400, 3)

# %%
plt.imshow(resize_img)
